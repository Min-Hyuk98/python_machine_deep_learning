# %% [markdown]
# # konlpy 형태소 분석기 성능비교

# %%
from konlpy.tag import Kkma
from konlpy.tag import Komoran
from konlpy.tag import Hannanum
# from konlpy.tag import Mecab
import MeCab
from konlpy.tag import Okt # Twitter 형태소분석기.

# 형태소 분석을 위한 객체 생성.
kkma = Kkma()
komoran = Komoran()
hannanum = Hannanum()
mecab = MeCab.Tagger()
okt = Okt()

# %% [markdown]
# ## 문장 분석 품질 비교

# %% [markdown]
# > ### 1. 띄어쓰기가 제대로 되어있지 않은 문장
# - mecab이 분류 잘됨
# - hannanum은 분류 잘 안됨

# %%
text = "아버지가방에들어가신다"

# %%
# 꼬꼬마 형태소 분석 결과
# pos = part-of-speech -> 품사
kkma.pos(text)
# Out:
# [('아버지', 'NNG'),
#  ('가방', 'NNG'),
#  ('에', 'JKM'),
#  ('들어가', 'VV'),
#  ('시', 'EPH'),
#  ('ㄴ다', 'EFN')]

# %%
kkma.morphs(text)
# Out:
# ['아버지', '가방', '에', '들어가', '시', 'ㄴ다']

# %%
# 코모란 형태소 분석 결과
komoran.pos(text)
# Out:
# [('아버지', 'NNG'),
#  ('가방', 'NNP'),
#  ('에', 'JKB'),
#  ('들어가', 'VV'),
#  ('시', 'EP'),
#  ('ㄴ다', 'EC')]

# %%
hannanum.pos(text)
# Out:
# [('아버지가방에들어가', 'N'), ('이', 'J'), ('시ㄴ다', 'E')]

# %%
mecab.parse(text)
# Out:
# '아버지\tNNG,*,F,아버지,*,*,*,*\n가\tJKS,*,F,가,*,*,*,*\n방\tNNG,장소,T,방,*,*,*,*\n에\tJKB,*,F,에,*,*,*,*\n들어가\tVV,*,F,들어가,*,*,*,*\n신다\tEP+EC,*,F,신다,Inflect,EP,EC,시/EP/*+ㄴ다/EC/*\nEOS\n'

# %%
okt.pos(text)
# Out:
# [('아버지', 'Noun'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가신다', 'Verb')]

# %% [markdown]
# > ### 2. 오탈자 때문에 불완전한 문장
# - komoran이 오탈자를 잘 잡아냄

# %%
text2 = "ㄱㅐㄴㅏ리가 피어있는 동산에 누워있고싶ㄷㅏ"

# %%
# 꼬꼬마 형태소 결과 출력하기.

print("꼬꼬마 : %s\n" % kkma.pos(text2))
print("코모란 : %s\n" % komoran.pos(text2))
print("한나눔 : %s\n" % hannanum.pos(text2))
print("mecab : %s\n" % mecab.parse(text2))
print("Okt : %s\n" % okt.pos(text2))

## 코모란이 오탈자를 잘 잡아준다
# Out:
# 꼬꼬마 : [('ㄱㅐㄴㅏ리', 'UN'), ('가', 'JKS'), ('피', 'VV'), ('어', 'ECD'), ('있', 'VXV'), ('는', 'ETD'), ('동산', 'NNG'), ('에', 'JKM'), ('눕', 'VV'), ('어', 'ECS'), ('있', 'VV'), ('고', 'ECE'), ('싶ㄷㅏ', 'UN')]
#
# 코모란 : [('개나리', 'NNP'), ('가', 'JKS'), ('피', 'VV'), ('어', 'EC'), ('있', 'VX'), ('는', 'ETM'), ('동산', 'NNP'), ('에', 'JKB'), ('눕', 'VV'), ('어', 'EC'), ('있', 'VX'), ('고', 'EC'), ('싶', 'VX'), ('다', 'EC')]
#
# 한나눔 : [('ㄱㅐㄴㅏ리', 'N'), ('가', 'J'), ('피', 'P'), ('어', 'E'), ('있', 'P'), ('는', 'E'), ('동산', 'N'), ('에', 'J'), ('누워있고싶ㄷㅏ', 'N')]
#
# mecab : ㄱ	NNG,*,F,ㄱ,*,*,*,*
# ㅐㄴㅏ리가	UNKNOWN,*,*,*,*,*,*,*
# 피	VV,*,F,피,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 있	VX,*,T,있,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 동산	NNG,장소,T,동산,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 누워	VV+EC,*,F,누워,Inflect,VV,EC,눕/VV/*+어/EC/*
# 있	VX,*,T,있,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 싶	VX,*,T,싶,*,*,*,*
# ㄷ	NNG,*,F,ㄷ,*,*,*,*
# ㅏ	UNKNOWN,*,*,*,*,*,*,*
# EOS
#
#
# Okt : [('ㄱㅐㄴㅏ', 'KoreanParticle'), ('리가', 'Noun'), ('피어있는', 'Verb'), ('동산', 'Noun'), ('에', 'Josa'), ('누워있고싶', 'Verb'), ('ㄷㅏ', 'KoreanParticle')]

# %% [markdown]
# > ### 3. 속도 비교
# - kkma가 가장느림
# - komoran, hannanum, okt는 속도 거의 비슷
# - mecab이 가장 빠름

# %%
text3 = """5G 이동통신망을 빌려 사용하는 ‘5G 알뜰폰’이 올해 도입되고, 내년부터는 의무화된다.
정부는 알뜰폰 사업자(MNVO)가 통신사(MNO)에 통신망을 빌리는 비용(도매대가)을 지난해보다 큰 폭으로 낮춰, 알뜰폰 요금 인하를 유도하기로 했다. 하지만 줄어드는 알뜰폰 시장을 살릴 수 있을지는 지켜봐야 하는 상황이다.
과학기술정보통신부는 알뜰폰 활성화 추진대책을 25일 발표했다. 알뜰폰 가입자는 800만명으로 이동통신 시장의 12%를 차지한다. 2011년 출시 뒤 저렴한 요금제로 통신비 부담을 낮춰왔다. 하지만 지난해 5월 통신 3사가 준보편제 요금을 내놓은 이후 알뜰폰 이탈 현상이 지속되고 있다.
우선 올해 안에 3개 이상의 5G 알뜰폰이 시장에 나온다. 통신사가 5G망을 알뜰폰 사업자에게 도매 제공할지 여부는 통신사 자율로 정한다. 앞서 LG유플러스는 오는 10월 알뜰폰 사업을 시작하는 KB국민은행에 5G망을 제공한다고 밝힌 바 있다. SK텔레콤와 KT도 특정 제휴사를 선택해 올해 안에 5G 알뜰폰을 내놓기로 했다.
내년부터는 5G 알뜰폰 제공이 의무화된다. 지난 22일자로 종료된 도매제공 의무제도의 유효기간을 2022년 9월22일까지 연장하는 전기통신사업법 개정안이 국회에서 통과되면, 관련 고시를 개정해 SK텔레콤의 5G망 도매제공을 의무화하겠다는 것이다.
과기정통부 관계자는 “SK텔레콤이 자사와 계약을 맺은 13개 알뜰폰 사업자에게 5G망을 의무 제공하면, 그 외 31개의 알뜰폰 사업자들이 경쟁에서 밀릴 것을 우려해 KT와 LG유플러스도 5G망을 제공하게 될 것”이라고 내다봤다.
알뜰폰 사업자가 상품을 만드는 방식 크게 2가지다. 하나는 통신사로부터 음성·문자·데이터를 도매로 사들인 뒤 이를 바탕으로 통신사보다 저렴한 요금제를 내놓는 방식(종량제 도매제공)이다. 이를 위해 정부는 도매대가 인하율을 음성 17.8%, 데이터 19.2%, 단문메시지 1.15%로, 지난해 음성 15.1%, 데이터 19.1%, 단문메시지 1.13%에 비해 높여 잡았다.
또 다른 방식은 일정비용을 통신사에 내고 통신사의 정액 요금제를 그대로 판매하면서, 그 차액의 범위에서 저렴한 요금제를 내놓는 방식(수익배분 도매제공)이다. 정부는 SK텔레콤의 준보편 요금제인 ‘T플랜 요금제’를 알뜰폰 사업자가 재판매할 수 있게 했다. 기존에 SK텔레콤이 도매제공했던 ‘밴드데이터 요금제’의 최고구간의 대가도 1.5%포인트 낮췄다.
알뜰폰 업계는 대체로 반기는 분위기지만, 알뜰폰 시장을 살릴 수 있을지에는 의구심을 갖고 있다. 업계 관계자는 “도매대가 인하율이 크고, 5G망을 제공하는 것은 긍정적”이라면서도 “수익배분 도매제공의 의무화, 설비를 가진 업체에 대한 접속료 정산 도입 등의 제도적 개선이 필요하다”고 말했다."""

# %%
# %%time
print(kkma.pos(text3)[:5])
# Out:
# [('5', 'NR'), ('G', 'OL'), ('이동', 'NNG'), ('통신망', 'NNG'), ('을', 'JKO')]
# Wall time: 3.05 s

# %%
# %%time
print(komoran.pos(text3)[:5])
# Out:
# [('5', 'SN'), ('G', 'SL'), ('이동', 'NNG'), ('통신망', 'NNG'), ('을', 'JKO')]
# Wall time: 305 ms

# %%
# %%time
print(hannanum.pos(text3)[:5])
# Out:
# [('5G', 'N'), ('이동통신망', 'N'), ('을', 'J'), ('빌리', 'P'), ('어', 'E')]
# Wall time: 1.57 s

# %%
# %%time
print(mecab.parse(text3))
# Out:
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 이동	NNG,행위,T,이동,*,*,*,*
# 통신망	NNG,*,T,통신망,Compound,*,*,통신/NNG/*+망/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 빌려	VV+EC,*,F,빌려,Inflect,VV,EC,빌리/VV/*+어/EC/*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# ‘	SY,*,*,*,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# ’	SY,*,*,*,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 올해	NNG,*,F,올해,Compound,*,*,올/NNG/*+해/NNG/*
# 도입	NNG,*,T,도입,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 내년	NNG,*,T,내년,*,*,*,*
# 부터	JX,*,F,부터,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 의무	NNG,*,F,의무,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 된다	XSV+EF,*,F,된다,Inflect,XSV,EF,되/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 정부	NNG,*,F,정부,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 사업자	NNG,*,F,사업자,Compound,*,*,사업/NNG/행위+자/NNG/*
# (	SSO,*,*,*,*,*,*,*
# MNVO	SL,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 통신사	NNG,*,F,통신사,Compound,*,*,통신/NNG/*+사/NNG/*
# (	SSO,*,*,*,*,*,*,*
# MNO	SL,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 통신망	NNG,*,T,통신망,Compound,*,*,통신/NNG/*+망/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 빌리	VV,*,F,빌리,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 비용	NNG,*,T,비용,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 도매	NNG,행위,F,도매,*,*,*,*
# 대가	NNG,*,F,대가,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 지난해	NNG,*,F,지난해,Compound,*,*,지난/NNG/*+해/NNG/*
# 보다	JKB,*,F,보다,*,*,*,*
# 큰	VA+ETM,*,T,큰,Inflect,VA,ETM,크/VA/*+ᆫ/ETM/*
# 폭	NNG,*,T,폭,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 낮춰	VV+EF,*,F,낮춰,Inflect,VV,EF,낮추/VV/*+어/EF/*
# ,	SC,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 요금	NNG,*,T,요금,*,*,*,*
# 인하	NNG,행위,F,인하,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 유도	NNG,*,F,유도,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 했	VV+EP,*,T,했,Inflect,VV,EP,하/VV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 줄어드	VV,*,F,줄어드,Inflect,VV,VV,줄어들/VV/*
# 는	ETM,*,T,는,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 시장	NNG,*,T,시장,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 살릴	VV+ETM,*,T,살릴,Inflect,VV,ETM,살리/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 을지	EC,*,F,을지,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 지켜봐야	VV+EC,*,F,지켜봐야,Inflect,VV,EC,지켜보/VV/*+아야/EC/*
# 하	VV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 상황	NNG,정적사태,T,상황,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 과학	NNG,*,T,과학,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 정보	NNG,*,F,정보,*,*,*,*
# 통신부	NNG,*,F,통신부,Compound,*,*,통신/NNG/*+부/NNG/*
# 는	JX,*,T,는,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 활성	NNG,상태변화,T,활성,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 추진	NNG,행위,T,추진,*,*,*,*
# 대책	NNG,*,T,대책,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 25	SN,*,*,*,*,*,*,*
# 일	NNBC,*,T,일,*,*,*,*
# 발표	NNG,행위,F,발표,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 가입자	NNG,*,F,가입자,Compound,*,*,가입/NNG/*+자/NNG/*
# 는	JX,*,T,는,*,*,*,*
# 800	SN,*,*,*,*,*,*,*
# 만	NR,*,T,만,*,*,*,*
# 명	NNBC,*,T,명,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 이동	NNG,행위,T,이동,*,*,*,*
# 통신	NNG,행위,T,통신,*,*,*,*
# 시장	NNG,*,T,시장,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 12	SN,*,*,*,*,*,*,*
# %	SY,*,*,*,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 차지	NNG,행위,F,차지,*,*,*,*
# 한다	XSV+EC,*,F,한다,Inflect,XSV,EC,하/XSV/*+ᆫ다/EC/*
# .	SY,*,*,*,*,*,*,*
# 2011	SN,*,*,*,*,*,*,*
# 년	NNBC,*,T,년,*,*,*,*
# 출시	NNG,*,F,출시,*,*,*,*
# 뒤	NNG,*,F,뒤,*,*,*,*
# 저렴	XR,*,T,저렴,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 요금제	NNP,*,F,요금제,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 통신비	NNG,*,F,통신비,Compound,*,*,통신/NNG/*+비/NNG/*
# 부담	NNG,행위,T,부담,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 낮춰	VV+EC,*,F,낮춰,Inflect,VV,EC,낮추/VV/*+어/EC/*
# 왔	VX+EP,*,T,왔,Inflect,VX,EP,오/VX/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 하지만	MAJ,*,T,하지만,*,*,*,*
# 지난해	NNG,*,F,지난해,Compound,*,*,지난/NNG/*+해/NNG/*
# 5	SN,*,*,*,*,*,*,*
# 월	NNBC,*,T,월,*,*,*,*
# 통신	NNG,행위,T,통신,*,*,*,*
# 3	SN,*,*,*,*,*,*,*
# 사	NR,*,F,사,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 준보	NNG,*,F,준보,*,*,*,*
# 편제	NNG,*,F,편제,*,*,*,*
# 요금	NNG,*,T,요금,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 내놓	VV,*,T,내놓,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 이후	NNG,*,F,이후,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 이탈	NNG,행위,T,이탈,*,*,*,*
# 현상	NNG,*,T,현상,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 지속	NNG,정적사태,T,지속,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 있	VX,*,T,있,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 우선	MAG,성분부사|시간부사,T,우선,*,*,*,*
# 올해	NNG,*,F,올해,Compound,*,*,올/NNG/*+해/NNG/*
# 안	NNG,장소,T,안,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 3	SN,*,*,*,*,*,*,*
# 개	NNBC,*,F,개,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 시장	NNG,*,T,시장,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 나온다	VV+EF,*,F,나온다,Inflect,VV,EF,나오/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 통신사	NNG,*,F,통신사,Compound,*,*,통신/NNG/*+사/NNG/*
# 가	JKS,*,F,가,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 망	NNG,*,T,망,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 사업자	NNG,*,F,사업자,Compound,*,*,사업/NNG/행위+자/NNG/*
# 에게	JKB,*,F,에게,*,*,*,*
# 도매	NNG,행위,F,도매,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 할지	XSV+EC,*,F,할지,Inflect,XSV,EC,하/XSV/*+ᆯ지/EC/*
# 여부	NNG,정적사태,F,여부,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 통신사	NNG,*,F,통신사,Compound,*,*,통신/NNG/*+사/NNG/*
# 자율	NNG,정적사태,T,자율,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 정한다	VV+EF,*,F,정한다,Inflect,VV,EF,정하/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 앞서	VV+EC,*,F,앞서,Inflect,VV,EC,앞서/VV/*+어/EC/*
# LG	SL,*,*,*,*,*,*,*
# 유	NNP,인명,F,유,*,*,*,*
# 플러스	NNP,인명,F,플러스,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 오	VV,*,F,오,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 10	SN,*,*,*,*,*,*,*
# 월	NNBC,*,T,월,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 사업	NNG,행위,T,사업,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 시작	NNG,행위,T,시작,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# KB	SL,*,*,*,*,*,*,*
# 국민은행	NNP,*,T,국민은행,Compound,*,*,국민/NNG/*+은행/NNG/*
# 에	JKB,*,F,에,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 망	NNG,*,T,망,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 한다고	XSV+EC,*,F,한다고,Inflect,XSV,EC,하/XSV/*+ᆫ다고/EC/*
# 밝힌	VV+ETM,*,T,밝힌,Inflect,VV,ETM,밝히/VV/*+ᆫ/ETM/*
# 바	NNB,*,F,바,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# SK	SL,*,*,*,*,*,*,*
# 텔레콤	NNP,*,T,텔레콤,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# KT	SL,*,*,*,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 특정	NNG,*,T,특정,*,*,*,*
# 제	MM,~수관형사,F,제,*,*,*,*
# 휴사	NNG,*,F,휴사,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 선택	NNG,행위,T,선택,*,*,*,*
# 해	XSV+EC,*,F,해,Inflect,XSV,EC,하/XSV/*+아/EC/*
# 올해	NNG,*,F,올해,Compound,*,*,올/NNG/*+해/NNG/*
# 안	NNG,장소,T,안,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 내놓	VV,*,T,내놓,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 했	VV+EP,*,T,했,Inflect,VV,EP,하/VV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 내년	NNG,*,T,내년,*,*,*,*
# 부터	JX,*,F,부터,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 의무	NNG,*,F,의무,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 된다	XSV+EF,*,F,된다,Inflect,XSV,EF,되/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 지난	VV+ETM,*,T,지난,Inflect,VV,ETM,지나/VV/*+ᆫ/ETM/*
# 22	SN,*,*,*,*,*,*,*
# 일자	NNG,*,F,일자,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 종료	NNG,행위,F,종료,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 도매	NNG,행위,F,도매,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 의무	NNG,*,F,의무,*,*,*,*
# 제도	NNG,*,F,제도,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 유효	NNG,*,F,유효,*,*,*,*
# 기간	NNG,*,T,기간,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 2022	SN,*,*,*,*,*,*,*
# 년	NNBC,*,T,년,*,*,*,*
# 9	SN,*,*,*,*,*,*,*
# 월	NNBC,*,T,월,*,*,*,*
# 22	SN,*,*,*,*,*,*,*
# 일	NNBC,*,T,일,*,*,*,*
# 까지	JX,*,F,까지,*,*,*,*
# 연장	NNG,*,T,연장,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 전기	NNG,*,F,전기,*,*,*,*
# 통신	NNG,행위,T,통신,*,*,*,*
# 사업	NNG,행위,T,사업,*,*,*,*
# 법	NNG,*,T,법,*,*,*,*
# 개정안	NNG,*,T,개정안,Compound,*,*,개정/NNG/*+안/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 국회	NNG,장소,F,국회,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 통과	NNG,행위,F,통과,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 면	EC,*,T,면,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 관련	NNG,정적사태,T,관련,*,*,*,*
# 고시	NNG,*,F,고시,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 개정	NNG,행위,T,개정,*,*,*,*
# 해	XSV+EC,*,F,해,Inflect,XSV,EC,하/XSV/*+아/EC/*
# SK	SL,*,*,*,*,*,*,*
# 텔레콤	NNP,*,T,텔레콤,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 망	NNG,*,T,망,*,*,*,*
# 도매	NNG,행위,F,도매,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 의무	NNG,*,F,의무,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 겠	EP,*,T,겠,*,*,*,*
# 다는	ETM,*,T,다는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 과기	NNG,*,F,과기,*,*,*,*
# 정통부	NNG,*,F,정통부,Compound,*,*,정통/NNG/*+부/NNG/*
# 관계자	NNG,*,F,관계자,Compound,*,*,관계/NNG/*+자/NNG/*
# 는	JX,*,T,는,*,*,*,*
# “	SSO,*,*,*,*,*,*,*
# SK	SL,*,*,*,*,*,*,*
# 텔레콤	NNP,*,T,텔레콤,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 자사	NNG,*,F,자사,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 계약	NNG,*,T,계약,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 맺	VV,*,T,맺,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 13	SN,*,*,*,*,*,*,*
# 개	NNBC,*,F,개,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 사업자	NNG,*,F,사업자,Compound,*,*,사업/NNG/행위+자/NNG/*
# 에게	JKB,*,F,에게,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 망	NNG,*,T,망,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 의무	NNG,*,F,의무,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 면	EC,*,T,면,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 외	NNB,*,F,외,*,*,*,*
# 31	SN,*,*,*,*,*,*,*
# 개	NNBC,*,F,개,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 사업자	NNG,*,F,사업자,Compound,*,*,사업/NNG/행위+자/NNG/*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 경쟁	NNG,행위,T,경쟁,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 밀릴	VV+ETM,*,T,밀릴,Inflect,VV,ETM,밀리/VV/*+ᆯ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 우려	NNG,정적사태,F,우려,*,*,*,*
# 해	XSV+EC,*,F,해,Inflect,XSV,EC,하/XSV/*+아/EC/*
# KT	SL,*,*,*,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# LG	SL,*,*,*,*,*,*,*
# 유	NNG,*,F,유,*,*,*,*
# 플러스	NNG,*,F,플러스,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 망	NNG,*,T,망,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 될	VV+ETM,*,T,될,Inflect,VV,ETM,되/VV/*+ᆯ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# ”	SSC,*,*,*,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 내	VX,*,F,내,*,*,*,*
# 다	EC,*,F,다,*,*,*,*
# 봤	VX+EP,*,T,봤,Inflect,VX,EP,보/VX/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 사업자	NNG,*,F,사업자,Compound,*,*,사업/NNG/행위+자/NNG/*
# 가	JKS,*,F,가,*,*,*,*
# 상품	NNG,*,T,상품,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만드	VV,*,F,만드,Inflect,VV,VV,만들/VV/*
# 는	ETM,*,T,는,*,*,*,*
# 방식	NNG,*,T,방식,*,*,*,*
# 크	VA,*,F,크,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 2	SN,*,*,*,*,*,*,*
# 가지	NNBC,*,F,가지,*,*,*,*
# 다	VCP+EF,*,F,다,Inflect,VCP,EF,이/VCP/*+다/EF/*
# .	SF,*,*,*,*,*,*,*
# 하나	NR,*,F,하나,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 통신사	NNG,*,F,통신사,Compound,*,*,통신/NNG/*+사/NNG/*
# 로부터	JKB,*,F,로부터,*,*,*,*
# 음성	NNG,*,T,음성,*,*,*,*
# ·	SC,*,*,*,*,*,*,*
# 문자	NNG,*,F,문자,*,*,*,*
# ·	SC,*,*,*,*,*,*,*
# 데이터	NNG,*,F,데이터,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 도매	NNG,행위,F,도매,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 사들인	VV+ETM,*,T,사들인,Inflect,VV,ETM,사들이/VV/*+ᆫ/ETM/*
# 뒤	NNG,*,F,뒤,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 바탕	NNG,*,T,바탕,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 통신사	NNG,*,F,통신사,Compound,*,*,통신/NNG/*+사/NNG/*
# 보다	JKB,*,F,보다,*,*,*,*
# 저렴	XR,*,T,저렴,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 요금제	NNP,*,F,요금제,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 내놓	VV,*,T,내놓,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 방식	NNG,*,T,방식,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 종량제	NNG,*,F,종량제,Compound,*,*,종량/NNG/*+제/NNG/*
# 도매	NNG,행위,F,도매,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# 정부	NNG,*,F,정부,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 도매	NNG,행위,F,도매,*,*,*,*
# 대가	NNG,*,F,대가,*,*,*,*
# 인하	NNG,행위,F,인하,*,*,*,*
# 율	XSN,*,T,율,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 음성	NNG,*,T,음성,*,*,*,*
# 17	SN,*,*,*,*,*,*,*
# .	SY,*,*,*,*,*,*,*
# 8	SN,*,*,*,*,*,*,*
# %,	SY,*,*,*,*,*,*,*
# 데이터	NNG,*,F,데이터,*,*,*,*
# 19	SN,*,*,*,*,*,*,*
# .	SY,*,*,*,*,*,*,*
# 2	SN,*,*,*,*,*,*,*
# %,	SY,*,*,*,*,*,*,*
# 단문	NNG,*,T,단문,*,*,*,*
# 메시지	NNG,*,F,메시지,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# .	SY,*,*,*,*,*,*,*
# 15	SN,*,*,*,*,*,*,*
# %	SY,*,*,*,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 지난해	NNG,*,F,지난해,Compound,*,*,지난/NNG/*+해/NNG/*
# 음성	NNG,*,T,음성,*,*,*,*
# 15	SN,*,*,*,*,*,*,*
# .	SY,*,*,*,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# %,	SY,*,*,*,*,*,*,*
# 데이터	NNG,*,F,데이터,*,*,*,*
# 19	SN,*,*,*,*,*,*,*
# .	SY,*,*,*,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# %,	SY,*,*,*,*,*,*,*
# 단문	NNG,*,T,단문,*,*,*,*
# 메시지	NNG,*,F,메시지,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# .	SY,*,*,*,*,*,*,*
# 13	SN,*,*,*,*,*,*,*
# %	SY,*,*,*,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 비해	VV+EC,*,F,비해,Inflect,VV,EC,비하/VV/*+아/EC/*
# 높여	VV+EC,*,F,높여,Inflect,VV,EC,높이/VV/*+어/EC/*
# 잡	VV,*,T,잡,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 다른	MM,~명사,T,다른,*,*,*,*
# 방식	NNG,*,T,방식,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 일정	NNG,*,T,일정,*,*,*,*
# 비용	NNG,*,T,비용,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 통신사	NNG,*,F,통신사,Compound,*,*,통신/NNG/*+사/NNG/*
# 에	JKB,*,F,에,*,*,*,*
# 내	VV,*,F,내,Inflect,VV,VV,나/VV/*
# 고	EC,*,F,고,*,*,*,*
# 통신사	NNG,*,F,통신사,Compound,*,*,통신/NNG/*+사/NNG/*
# 의	JKG,*,F,의,*,*,*,*
# 정액	NNG,*,T,정액,*,*,*,*
# 요금제	NNP,*,F,요금제,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 그대로	MAG,성분부사|양태부사,F,그대로,*,*,*,*
# 판매	NNG,행위,F,판매,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 면서	EC,*,F,면서,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 차액	NNG,*,T,차액,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 범위	NNG,*,F,범위,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 저렴	XR,*,T,저렴,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 요금제	NNP,*,F,요금제,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 내놓	VV,*,T,내놓,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 방식	NNG,*,T,방식,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 수익	NNG,*,T,수익,*,*,*,*
# 배분	NNG,행위,T,배분,*,*,*,*
# 도매	NNG,행위,F,도매,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 정부	NNG,*,F,정부,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# SK	SL,*,*,*,*,*,*,*
# 텔레콤	NNP,*,T,텔레콤,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 준	XPN,*,T,준,*,*,*,*
# 보편	NNG,*,T,보편,*,*,*,*
# 요금	NNG,*,T,요금,*,*,*,*
# 제인	NNG,*,T,제인,*,*,*,*
# ‘	SY,*,*,*,*,*,*,*
# T	SL,*,*,*,*,*,*,*
# 플랜	NNG,*,T,플랜,*,*,*,*
# 요금제	NNP,*,F,요금제,*,*,*,*
# ’	SY,*,*,*,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 사업자	NNG,*,F,사업자,Compound,*,*,사업/NNG/행위+자/NNG/*
# 가	JKS,*,F,가,*,*,*,*
# 재	XPN,*,F,재,*,*,*,*
# 판매	NNG,행위,F,판매,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 했	VX+EP,*,T,했,Inflect,VX,EP,하/VX/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 기존	NNG,*,T,기존,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# SK	SL,*,*,*,*,*,*,*
# 텔레콤	NNP,*,T,텔레콤,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 도매	NNG,행위,F,도매,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 던	ETM,*,T,던,*,*,*,*
# ‘	SY,*,*,*,*,*,*,*
# 밴드	NNG,*,F,밴드,*,*,*,*
# 데이터	NNG,*,F,데이터,*,*,*,*
# 요금제	NNP,*,F,요금제,*,*,*,*
# ’	SY,*,*,*,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 최고	NNG,*,F,최고,*,*,*,*
# 구간	NNG,*,T,구간,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 대가	NNG,*,F,대가,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# .	SY,*,*,*,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# %	SY,*,*,*,*,*,*,*
# 포인트	NNG,*,F,포인트,*,*,*,*
# 낮췄	VV+EP,*,T,낮췄,Inflect,VV,EP,낮추/VV/*+었/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 업계	NNG,*,F,업계,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 대체로	MAG,*,F,대체로,*,*,*,*
# 반기	VV,*,F,반기,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 분위기	NNG,*,F,분위기,*,*,*,*
# 지만	VCP+EC,*,T,지만,Inflect,VCP,EC,이/VCP/*+지만/EC/*
# ,	SC,*,*,*,*,*,*,*
# 알뜰	NNG,*,T,알뜰,*,*,*,*
# 폰	NNG,*,T,폰,*,*,*,*
# 시장	NNG,*,T,시장,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 살릴	VV+ETM,*,T,살릴,Inflect,VV,ETM,살리/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 을지	EC,*,F,을지,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 의구심	NNG,정적사태,T,의구심,Compound,*,*,의구/NNG/*+심/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 갖	VV,*,T,갖,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 있	VX,*,T,있,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 업계	NNG,*,F,업계,*,*,*,*
# 관계자	NNG,*,F,관계자,Compound,*,*,관계/NNG/*+자/NNG/*
# 는	JX,*,T,는,*,*,*,*
# “	SSO,*,*,*,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 매대	NNG,*,F,매대,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 인하	NNG,행위,F,인하,*,*,*,*
# 율	XSN,*,T,율,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 크	VA,*,F,크,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 5	SN,*,*,*,*,*,*,*
# G	SL,*,*,*,*,*,*,*
# 망	NNG,*,T,망,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 긍정	NNG,행위,T,긍정,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# ”	SSC,*,*,*,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라면	EC,*,T,라면,*,*,*,*
# 서도	NNG,*,F,서도,*,*,*,*
# “	SSO,*,*,*,*,*,*,*
# 수익	NNG,*,T,수익,*,*,*,*
# 배분	NNG,행위,T,배분,*,*,*,*
# 도매	NNG,행위,F,도매,*,*,*,*
# 제공	NNG,행위,T,제공,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 의무	NNG,*,F,의무,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 설비	NNG,*,F,설비,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 가진	VV+ETM,*,T,가진,Inflect,VV,ETM,가지/VV/*+ᆫ/ETM/*
# 업체	NNG,*,F,업체,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 접	NNBC,*,T,접,*,*,*,*
# 속료	NNG,*,F,속료,*,*,*,*
# 정산	NNG,*,T,정산,*,*,*,*
# 도입	NNG,*,T,도입,*,*,*,*
# 등	NNB,*,T,등,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 제도	NNG,*,F,제도,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 개선	NNG,행위,T,개선,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 필요	NNG,정적사태,F,필요,*,*,*,*
# 하	XSA,*,F,하,*,*,*,*
# 다	EC,*,F,다,*,*,*,*
# ”	SSC,*,*,*,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# EOS
#
# Wall time: 3 ms

# %%
# %%time
print(okt.pos(text3)[:5])
# Out:
# [('5', 'Number'), ('G', 'Alpha'), ('이', 'Determiner'), ('동', 'Modifier'), ('통신망', 'Noun')]
# Wall time: 696 ms
