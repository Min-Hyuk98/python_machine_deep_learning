# %% [markdown]
# # Tensorflow 2.0의 이해

# %% [markdown]
# ## Import modules

# %%
import tensorflow as tf

# %% [markdown]
# ## 데이터 불러오기

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# mnist데이터는 0~255로 표현되어 있다..
# 정규화해주기 위해 255로 나눔

# %% [markdown]
# ## 네트워크 구조 정의

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)), ##입력데이터는 28X28 그림이므로 이렇게 넣어줌
                                    tf.keras.layers.Dense(128, activation='relu'), ## activation func으로 relu 사용
                                    tf.keras.layers.Dropout(0.2), ## 0.2의 확률로 hidden layer의 노드를 남김 --> overfittin 방지
                                    tf.keras.layers.Dense(10, activation='softmax')]) ## 마지막 layer의 activation func은 softmax 사용 --> multi classification

## 순서대로 layer를 입력해주면 됨

# %% [markdown]
# ## Keras 모델 Compile

# %%
model.compile(optimizer='adam',  ## 최적화 방식
              loss = 'sparse_categorical_crossentropy',  ## 손실함수
              metrics=['accuracy']) ## 평가방식

# %% [markdown]
# ## 학습 수행

# %%
model.fit(x_train, y_train, epochs = 5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.2998 - accuracy: 0.9127
# Epoch 2/5
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.1402 - accuracy: 0.9582
# Epoch 3/5
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.1062 - accuracy: 0.9679
# Epoch 4/5
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.0871 - accuracy: 0.9737
# Epoch 5/5
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.0753 - accuracy: 0.9767

# %% [markdown]
# ## 학습 결과 테스트

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
